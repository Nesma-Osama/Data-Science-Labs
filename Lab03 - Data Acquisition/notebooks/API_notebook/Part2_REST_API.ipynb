# %% [markdown]
# # <span style="color:blue">PART 2: REST API INTEGRATION</span>

# %% [markdown]
# ---
# ## 2.1 Understanding APIs: The Restaurant Analogy
#
# Imagine a **restaurant**:
#
# | Concept | API Equivalent |
# |---|---|
# | 🍳 Kitchen | Server with data |
# | 📋 Menu | API documentation |
# | 🧑‍🍳 Waiter | API endpoints |
# | 📝 Your order | HTTP request |
# | 🍽️ Your food | HTTP response |
#
# > You **don't** go into the kitchen (database). You tell the waiter what you want, and they bring it to you.
#
# ---
#
# ### <span style="color:blue">HTTP Methods = Actions</span>
#
# | Method | Meaning | Description |
# |---|---|---|
# | **`GET`** | "Show me the menu" | Retrieve data |
# | **`POST`** | "I want to order this" | Create new data |
# | **`PUT`** | "Change my entire order" | Replace data |
# | **`PATCH`** | "Add extra cheese" | Update part of data |
# | **`DELETE`** | "Cancel my order" | Remove data |
#
# ---
#
# ### <span style="color:blue">Status Codes = Kitchen's Response</span>
#
# | Code | Message | Meaning |
# |---|---|---|
# | **200** | OK | "Here's your food!" |
# | **201** | Created | "Order placed successfully!" |
# | <span style="color:red">**400**</span> | Bad Request | "That's not on the menu" |
# | <span style="color:red">**401**</span> | Unauthorized | "You need to pay first" |
# | <span style="color:red">**404**</span> | Not Found | "We don't have that dish" |
# | <span style="color:red">**429**</span> | Too Many Requests | "You're ordering too fast!" |
# | <span style="color:red">**500**</span> | Server Error | "Kitchen is on fire" |

# %% [markdown]
# ---
# ## 2.2 Real Example: GitHub API
#
# **GitHub** provides free APIs to access public repository data. Let's explore!
#
# > 📌 We use the `requests` library to make HTTP calls and `pandas` to work with the data.

# %%
import requests
import pandas as pd
import json
from datetime import datetime


# Example 1: Get repository information
def get_repo_info(owner, repo):
    """
    Fetch information about a GitHub repository.

    Args:
        owner: Repository owner (e.g., 'pandas-dev')
        repo: Repository name (e.g., 'pandas')

    Returns:
        dict: Repository information
    """
    # API endpoint - GitHub's REST API base URL + path to specific repo
    url = f'https://api.github.com/repos/{owner}/{repo}'

    # Make GET request to the API endpoint
    response = requests.get(url)

    # Check status code to determine if request succeeded
    print(f"Status Code: {response.status_code}")
    print(f"Response Headers:")
    for key, value in list(response.headers.items())[:5]:
        print(f"  {key}: {value}")

    # Parse JSON response only if request was successful
    if response.status_code == 200:
        data = response.json()

        # Extract only the relevant fields we care about
        repo_info = {
            'name': data['name'],
            'full_name': data['full_name'],
            'description': data['description'],
            'stars': data['stargazers_count'],
            'forks': data['forks_count'],
            'watchers': data['watchers_count'],
            'open_issues': data['open_issues_count'],
            'language': data['language'],
            'created_at': data['created_at'],
            'updated_at': data['updated_at'],
            'size': data['size'],
            'license': data['license']['name'] if data['license'] else 'No license',
        }
        return repo_info
    else:
        print(f"Error: {response.status_code}")
        return None


# Try it!
repo_info = get_repo_info('pandas-dev', 'pandas')

if repo_info:
    print("\n=== Repository Information ===")
    for key, value in repo_info.items():
        print(f"{key}: {value}")
# Out:
# Status Code: 200
# Response Headers:
#   Date: Tue, 03 Mar 2026 19:37:51 GMT
#   Content-Type: application/json; charset=utf-8
#   Cache-Control: public, max-age=60, s-maxage=60
#   Vary: Accept,Accept-Encoding, Accept, X-Requested-With
#   ETag: W/"da6cbc4d3375843fd0c0c617e42954b49fd97e3b6f8bae9da85aa178753804e9"
#
# === Repository Information ===
# name: pandas
# full_name: pandas-dev/pandas
# description: Flexible and powerful data analysis / manipulation library for Python, providing labeled data structures similar to R data.frame objects, statistical functions, and much more
# stars: 48025
# forks: 19710
# watchers: 48025
# open_issues: 3689
# language: Python
# created_at: 2010-08-24T01:37:33Z
# updated_at: 2026-03-03T17:43:29Z
# size: 384104
# license: BSD 3-Clause "New" or "Revised" License

# %% [markdown]
# ### Expected Output:
# ```
# Status Code: 200
# Response Headers:
#   Content-Type: application/json
#   X-RateLimit-Limit: 60
#   X-RateLimit-Remaining: 59
#   ...
#
# === Repository Information ===
# name: pandas
# full_name: pandas-dev/pandas
# description: Flexible and powerful data analysis / manipulation library for Python
# stars: 43256
# forks: 17843
# ...
# ```
#
# ---
#
# ### <span style="color:blue">Understanding the Response</span>
#
# An **HTTP Response** has 3 parts:
#
# ```
# 1. Status Line:   HTTP/1.1 200 OK
#
# 2. Headers:
#    Content-Type: application/json
#    X-RateLimit-Limit: 60        <-- Max requests per hour
#    X-RateLimit-Remaining: 59    <-- Requests left
#
# 3. Body (JSON):
#    {
#      "name": "pandas",
#      "stars": 43256,
#      ...
#    }
# ```

# %% [markdown]
# ---
# ## 2.3 Handling Authentication
#
# Many APIs require **authentication** to:
# 1. Track usage
# 2. Prevent abuse
# 3. Provide personalized data
#
# ---
#
# ### <span style="color:blue">Types of Authentication</span>
#
# #### **Type 1: API Key in Header** *(Most Common)*

# %%
import os
from dotenv import load_dotenv  # pip install python-dotenv

# Load API key from .env file (keeps secrets out of your code)
load_dotenv()

api_key = os.getenv('GITHUB_TOKEN')

# Add the token to request headers for authentication
headers = {
    'Authorization': f'Bearer {api_key}',  # Token-based auth
    'Accept': 'application/vnd.github.v3+json',  # Tell server what format we want
    'User-Agent': 'Library-Tutorial-App',  # Identify your app
}

url = 'https://api.github.com/repos/pandas-dev/pandas'
response = requests.get(url, headers=headers)

# %% [markdown]
# #### Create a `.env` file in your project directory:
#
# ```
# GITHUB_TOKEN=ghp_your_token_here
# OPENWEATHER_KEY=your_key_here
# ```
#
# #### <span style="color:red">⚠️ Why `.env`?</span>
# - **Never** hardcode secrets in code!
# - Different keys for dev/production
# - Keeps secrets out of version control
#
# #### Add to `.gitignore`:
# ```
# .env
# *.env
# ```
#
# ---
#
# #### **Type 2: API Key in Query Parameters**

# %%
# Example: OpenWeather API uses key as a query parameter
api_key = os.getenv('OPENWEATHER_KEY')

# Parameters are automatically appended to the URL as ?q=Cairo&appid=...&units=metric
params = {
    'q': 'Cairo',
    'appid': api_key,
    'units': 'metric',  # Celsius instead of Kelvin
}

response = requests.get(
    'https://api.openweathermap.org/data/2.5/weather', params=params
)

# %% [markdown]
# #### **Type 3: OAuth** *(Complex but Secure)*

# %%
# OAuth flow (simplified):
# 1. User authorizes your app
# 2. You get an access token
# 3. Use token for requests
# This is beyond our scope but good to know!

# %% [markdown]
# ---
# ## <span style="color:blue">2.4 Advanced: Pagination</span>
#
# **Problem**: API returns 100 results, but there are **10,000!**
#
# **Solution**: **Pagination** — fetch data in multiple pages, just like a book.
#
# ### <span style="color:blue">Pagination Strategies</span>
#
# **1. Page-based (GitHub):**
# ```
# /repos?page=1&per_page=100
# /repos?page=2&per_page=100
# ```
#
# **2. Offset-based:**
# ```
# /repos?offset=0&limit=100
# /repos?offset=100&limit=100
# ```
#
# **3. Cursor-based** *(most efficient)*:
# ```
# /repos?cursor=abc123
# /repos?cursor=def456
#
# Response includes next cursor:
# {
#   "data": [...],
#   "next_cursor": "def456"
# }
# ```

# %%
import time


def get_all_repos(org_name, max_pages=None):
    """
    Fetch all repositories for an organization using pagination.
    GitHub API returns 30 repos per page by default.
    """
    all_repos = []
    page = 1

    while True:
        # Check if we've reached max_pages (useful for testing/limiting)
        if max_pages and page > max_pages:
            break

        print(f"Fetching page {page}...")

        # Add page parameter to tell the API which chunk of results we want
        params = {'page': page, 'per_page': 100}  # Max allowed by GitHub

        url = f'https://api.github.com/orgs/{org_name}/repos'
        response = requests.get(url, params=params)

        if response.status_code != 200:
            print(f"Error: {response.status_code}")
            break

        data = response.json()

        # If no data returned, we've gone past the last page
        if not data or len(data) == 0:
            print("No more results!")
            break

        all_repos.extend(data)
        page += 1

        # Be polite - wait between requests to avoid rate limiting
        time.sleep(0.5)

    return all_repos


# Example: Get all pandas-dev repos (limit to 3 pages for demo)
repos = get_all_repos('pandas-dev', max_pages=3)
print(f"\nFetched {len(repos)} repositories")

# Convert list of dicts to a clean DataFrame
df = pd.DataFrame(
    [
        {
            'name': repo['name'],
            'stars': repo['stargazers_count'],
            'language': repo['language'],
            'description': repo['description'],
        }
        for repo in repos
    ]
)

print("\nTop 10 by Stars:")
print(df.sort_values('stars', ascending=False).head(10))

# %% [markdown]
# ---
# ## 2.5 Rate Limiting & Retry Logic
#
# <span style="color:red">**Problem**</span>: APIs limit requests to prevent abuse.
#
# ### GitHub Rate Limits:
# - **Unauthenticated**: `60` requests/hour
# - **Authenticated**: `5,000` requests/hour
#
# ---
#
# ### <span style="color:blue">Custom Rate Limiter Class</span>

# %%
import time
from datetime import datetime


class RateLimiter:
    """
    Smart rate limiter that tracks API usage.
    Uses a sliding time window to count recent requests.
    """

    def __init__(self, max_requests=60, time_window=3600):
        """
        Args:
            max_requests: Maximum requests allowed in the time window
            time_window: Time window in seconds (3600 = 1 hour)
        """
        self.max_requests = max_requests
        self.time_window = time_window
        self.requests = []  # List of timestamps of past requests

    def wait_if_needed(self):
        """Wait if we've hit the rate limit before making a new request."""
        now = time.time()

        # Remove old timestamps outside the sliding time window
        self.requests = [
            req_time for req_time in self.requests if now - req_time < self.time_window
        ]

        # If we've used up our quota, sleep until the oldest request expires
        if len(self.requests) >= self.max_requests:
            oldest_request = self.requests[0]
            sleep_time = self.time_window - (now - oldest_request)
            if sleep_time > 0:
                print(
                    f"⏰ Rate limit reached. Sleeping for {sleep_time:.1f} seconds..."
                )
                time.sleep(sleep_time)
            self.requests = []  # Clear after sleeping

        # Record the timestamp of this new request
        self.requests.append(now)


# Usage: 10 requests per minute limit
limiter = RateLimiter(max_requests=10, time_window=60)

url = 'https://api.github.com/repos/pandas-dev/pandas'
for i in range(15):
    limiter.wait_if_needed()  # Automatically pauses if limit is hit
    response = requests.get(url)
    print(f"Request {i+1} completed")
# Out:
# Request 1 completed
# Request 2 completed
# Request 3 completed
# Request 4 completed
# Request 5 completed
# Request 6 completed
# Request 7 completed
# Request 8 completed
# Request 9 completed
# Request 10 completed
# ⏰ Rate limit reached. Sleeping for 48.1 seconds...
# Request 11 completed
# Request 12 completed
# Request 13 completed
# Request 14 completed
# Request 15 completed

# %% [markdown]
# ### <span style="color:blue">Checking API Limits from Headers</span>

# %%
def check_rate_limit(response):
    """
    Check rate limit info from response headers.
    GitHub includes rate limit details in every response.
    """
    if 'X-RateLimit-Limit' in response.headers:
        limit = int(response.headers['X-RateLimit-Limit'])
        remaining = int(response.headers['X-RateLimit-Remaining'])
        reset_timestamp = int(response.headers['X-RateLimit-Reset'])
        reset_time = datetime.fromtimestamp(reset_timestamp)

        print(f"Rate Limit: {remaining}/{limit}")
        print(f"Resets at: {reset_time}")

        # Warn when running low on available requests
        if remaining < 10:
            print("⚠️ Warning: Low on API requests!")

        return remaining
    return None


url = 'https://api.github.com/repos/pandas-dev/pandas'
response = requests.get(url)
check_rate_limit(response)
# Out:
# Rate Limit: 41/60
# Resets at: 2026-03-03 22:37:51
# 41

# %% [markdown]
# ### <span style="color:blue">Automatic Retry with Exponential Backoff</span>
#
# **What is Exponential Backoff?**
#
# Instead of hammering the server after a failure, we **wait progressively longer** between retries:
#
# ```
# Attempt 1: Fails → Wait  1 second
# Attempt 2: Fails → Wait  2 seconds
# Attempt 3: Fails → Wait  4 seconds
# Attempt 4: Fails → Wait  8 seconds
# Attempt 5: Success! ✅
# ```

# %%
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry


def create_robust_session():
    """
    Create requests session with automatic retry logic.
    The session will automatically retry failed requests using exponential backoff.
    """
    session = requests.Session()

    # Define retry strategy - what to retry, how many times, and how long to wait
    retry_strategy = Retry(
        total=5,  # Maximum number of retries
        backoff_factor=1,  # Wait 0, 1, 2, 4, 8 seconds between retries
        status_forcelist=[429, 500, 502, 503, 504],  # Retry on these status codes
        allowed_methods=["HEAD", "GET", "OPTIONS", "POST"],  # Methods to retry
    )

    # Mount the retry adapter for both http and https
    adapter = HTTPAdapter(max_retries=retry_strategy)
    session.mount("http://", adapter)
    session.mount("https://", adapter)

    return session


# Usage - just use this session like you would requests.get()
session = create_robust_session()
response = session.get('https://api.github.com/repos/pandas-dev/pandas')
print(f"Status: {response.status_code}")
# Out:
# Status: 200

# %% [markdown]
# ---
# ## 2.6 Error Handling & Logging
#
# **Robust code** anticipates failures and records what happened for debugging.

# %%
import logging
from datetime import datetime

# Configure logging to write to both a file AND the console
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('api_requests.log'),  # Saves to disk
        logging.StreamHandler(),  # Also print to console
    ],
)

logger = logging.getLogger(__name__)


def fetch_with_error_handling(url, max_retries=3):
    """
    Robust API fetch with comprehensive error handling.
    Handles: timeouts, connection errors, rate limits, server errors, bad JSON.
    """
    for attempt in range(max_retries):
        try:
            logger.info(f"Attempt {attempt + 1}/{max_retries}: GET {url}")
            response = requests.get(url, timeout=10)  # Don't wait more than 10 seconds

            # Handle each status code type differently
            if response.status_code == 200:
                logger.info(f"✓ Success: {url}")
                return response.json()

            elif response.status_code == 404:
                logger.error(f"✗ Not Found: {url}")
                return None  # No point retrying - resource doesn't exist

            elif response.status_code == 429:
                # Server tells us how long to wait in the Retry-After header
                retry_after = int(response.headers.get('Retry-After', 60))
                logger.warning(f"Rate limited. Waiting {retry_after}s...")
                time.sleep(retry_after)
                continue

            elif response.status_code >= 500:
                # Server error - retry with exponential backoff
                logger.error(f"Server error ({response.status_code}). Retrying...")
                time.sleep(2**attempt)  # 1, 2, 4 seconds
                continue

            else:
                logger.error(f"HTTP {response.status_code}: {url}")
                response.raise_for_status()

        except requests.exceptions.Timeout:
            logger.warning(f"Timeout on attempt {attempt + 1}")
            if attempt < max_retries - 1:
                time.sleep(2**attempt)

        except requests.exceptions.ConnectionError as e:
            logger.error(f"Connection error: {e}")
            if attempt < max_retries - 1:
                time.sleep(2**attempt)

        except json.JSONDecodeError:
            logger.error("Invalid JSON response")  # Server returned non-JSON
            return None

        except Exception as e:
            logger.error(f"Unexpected error: {e}")
            return None

    logger.error(f"Failed after {max_retries} attempts")
    return None


# Usage
data = fetch_with_error_handling('https://api.github.com/repos/python/cpython')
if data:
    print(f"Repo: {data['full_name']}, Stars: {data['stargazers_count']}")

# %% [markdown]
# **Expected Log Output:**
# ```
# 2024-03-15 10:30:45 - __main__ - INFO - Attempt 1/3: GET https://api.github.com/...
# 2024-03-15 10:30:46 - __main__ - INFO - ✓ Success: https://api.github.com/...
# ```

# %% [markdown]
# ---
# ## 2.7 Building a Reusable API Client
#
# Combining everything we've learned into a **clean, professional `GitHubAPI` class** that can be reused across projects.

# %%
import os
from requests.adapters import HTTPAdapter
from urllib3.util.retry import Retry
import logging
from datetime import datetime

# %%
class GitHubAPI:
    """
    Reusable GitHub API client with all best practices:
    - Session management with retry logic
    - Rate limiting
    - Authentication via token
    - Logging
    """

    def __init__(self, token=None):
        self.base_url = 'https://api.github.com'
        self.session = self._create_session()  # Robust session with retries
        self.rate_limiter = RateLimiter(
            max_requests=5000, time_window=3600
        )  # Authenticated limits

        # Add authentication token if provided
        if token:
            self.session.headers.update({'Authorization': f'Bearer {token}'})

        # Always set these headers for proper API communication
        self.session.headers.update(
            {
                'Accept': 'application/vnd.github.v3+json',
                'User-Agent': 'Library-Tutorial/1.0',
            }
        )

        self.logger = logging.getLogger(self.__class__.__name__)

    def _create_session(self):
        """Create session with retry logic (private method)."""
        session = requests.Session()
        retry_strategy = Retry(
            total=3, backoff_factor=1, status_forcelist=[429, 500, 502, 503, 504]
        )
        adapter = HTTPAdapter(max_retries=retry_strategy)
        session.mount("http://", adapter)
        session.mount("https://", adapter)
        return session

    def get(self, endpoint, params=None):
        """Make GET request with rate limiting."""
        self.rate_limiter.wait_if_needed()  # Respect rate limits
        url = f"{self.base_url}/{endpoint.lstrip('/')}"

        try:
            response = self.session.get(url, params=params, timeout=10)
            response.raise_for_status()  # Raises exception for 4xx/5xx
            self.logger.info(f"GET {endpoint} - Status: {response.status_code}")

            # Peek at remaining rate limit with each response
            remaining = check_rate_limit(response)
            return response.json()

        except Exception as e:
            self.logger.error(f"Error fetching {endpoint}: {e}")
            raise

    def get_repo(self, owner, repo):
        """Get repository information."""
        return self.get(f'/repos/{owner}/{repo}')

    def get_user_repos(self, username):
        """Get all repositories for a user."""
        return self.get(f'/users/{username}/repos', params={'per_page': 100})

    def search_repos(self, query, language=None, min_stars=None):
        """
        Search repositories.

        Args:
            query: Search query string
            language: Filter by programming language
            min_stars: Minimum stars required

        Returns:
            list: Repository results
        """
        # Build search query by combining filters with spaces
        q_parts = [query]
        if language:
            q_parts.append(f"language:{language}")
        if min_stars:
            q_parts.append(f"stars:>={min_stars}")

        q = ' '.join(q_parts)
        results = self.get('/search/repositories', params={'q': q})
        return results['items']

    def to_dataframe(self, repos):
        """Convert repository list to DataFrame for analysis."""
        data = []
        for repo in repos:
            data.append(
                {
                    'name': repo['name'],
                    'full_name': repo['full_name'],
                    'description': repo.get('description'),
                    'stars': repo['stargazers_count'],
                    'forks': repo['forks_count'],
                    'language': repo.get('language'),
                    'created_at': repo['created_at'],
                    'updated_at': repo['updated_at'],
                }
            )
        return pd.DataFrame(data)


# ============================
# Usage Examples
# ============================

api = GitHubAPI(token=os.getenv('GITHUB_TOKEN'))  # Authenticated (5000 req/hr)

# Get a single repository
repo = api.get_repo('pandas-dev', 'pandas')
print(f"Stars: {repo['stargazers_count']}")

# Search repositories with filters
python_repos = api.search_repos('machine learning', language='python', min_stars=1000)
df = api.to_dataframe(python_repos)
print(df.head())
# Out:
# Rate Limit: 40/60
# Resets at: 2026-03-03 22:37:51
# Stars: 48025
# Rate Limit: 9/10
# Resets at: 2026-03-03 21:50:14
# ⚠️ Warning: Low on API requests!
#                         name                                 full_name  \
# 0   awesome-machine-learning     josephmisiti/awesome-machine-learning
# 1            MachineLearning                      wepe/MachineLearning
# 2           Machine-Learning             Jack-Cherish/Machine-Learning
# 3     MachineLearning_Python          lawlite19/MachineLearning_Python
# 4  machine_learning_examples  lazyprogrammer/machine_learning_examples
#
#                                          description  stars  forks language  \
# 0  A curated list of awesome Machine Learning fra...  71805  15329   Python
# 1           Basic Machine Learning and Deep Learning   5647   3213   Python
# 2  :zap:机器学习实战（Python3）：kNN、决策树、贝叶斯、逻辑回归、SVM、线性回归...  10237   5108   Python
# 3                                     机器学习算法python实现   8364   2510   Python
# 4  A collection of machine learning examples and ...   8827   6446   Python
#
#              created_at            updated_at
# 0  2014-07-15T19:11:19Z  2026-03-03T19:25:19Z
# 1  2014-12-05T14:53:17Z  2026-03-02T06:51:38Z
# 2  2017-03-25T07:32:37Z  2026-03-03T14:48:03Z
# 3  2016-10-17T15:44:59Z  2026-03-03T12:11:12Z
# 4  2014-07-31T23:40:45Z  2026-03-01T10:19:10Z

# %% [markdown]
# ---
# ## 2.8 Working with Different Response Formats
#
# APIs don't always respond with JSON — here's how to handle the two most common formats.
#
# ---
#
# ### <span style="color:blue">JSON (Most Common)</span>

# %%
# Simple JSON - direct parsing
response = requests.get('https://api.github.com/repos/pandas-dev/pandas')
data = response.json()

# Nested JSON - requires flattening for DataFrame use
data = {
    "user": {
        "name": "Ahmed",
        "address": {"city": "Cairo", "country": "Egypt"},
        "repositories": [
            {"name": "repo1", "stars": 10},
            {"name": "repo2", "stars": 25},
        ],
    }
}

# Flatten nested JSON with json_normalize - great for deeply nested responses
df = pd.json_normalize(
    data['user']['repositories'], sep='_'  # Use underscore to separate nested keys
)
print("Simple flatten:")
print(df)

# Or access nested data with record_path and meta
# record_path = which nested list to expand as rows
# meta = which parent fields to carry along as columns
df = pd.json_normalize(
    data,
    record_path=['user', 'repositories'],
    meta=[['user', 'name'], ['user', 'address', 'city']],
    meta_prefix='user_',
)
print("\nWith metadata:")
print(df)
# Out:
# Simple flatten:
#     name  stars
# 0  repo1     10
# 1  repo2     25
#
# With metadata:
#     name  stars user_user.name user_user.address.city
# 0  repo1     10          Ahmed                  Cairo
# 1  repo2     25          Ahmed                  Cairo

# %% [markdown]
# ### <span style="color:blue">XML</span>
#
# Some older APIs (e.g., government data, RSS feeds) return XML instead of JSON.

# %%
import xml.etree.ElementTree as ET

# Sample XML response from an API
xml_string = """
<library>
  <book id="1">
    <title>Python Basics</title>
    <author>John Doe</author>
    <year>2023</year>
  </book>
  <book id="2">
    <title>Data Science</title>
    <author>Jane Smith</author>
    <year>2024</year>
  </book>
</library>
"""

# Parse the XML string into a tree structure
root = ET.fromstring(xml_string)

# Navigate the tree and extract data into a list of dicts
books = []
for book in root.findall(
    './/book'
):  # './/book' finds all <book> tags anywhere in the tree
    books.append(
        {
            'id': book.get('id'),  # Get XML attribute
            'title': book.find('title').text,  # Get text content of child tag
            'author': book.find('author').text,
            'year': int(book.find('year').text),
        }
    )

# Convert to DataFrame for easy analysis
df = pd.DataFrame(books)
print(df)
# Out:
#   id          title      author  year
# 0  1  Python Basics    John Doe  2023
# 1  2   Data Science  Jane Smith  2024

# %% [markdown]
# ---
# ## <span style="color:blue">2.9 Graded Exercise 2: GitHub Repository Analysis</span>
#
# **Scenario**: Analyze GitHub repositories to understand popular technologies.
#
# ---
#
# ### 📋 Task 1: Repository Information *(15 points)*
#
# **1.1** *(5 points)* Fetch information for these repositories:
# - `tensorflow/tensorflow`
# - `pytorch/pytorch`
# - `scikit-learn/scikit-learn`
#
# Create a **DataFrame** with columns: `name`, `stars`, `forks`, `language`, `open_issues`, `created_date`
#
# Save as: **`task1_github.csv`**

# %%
def task1_fetch_repos():
    """
    Fetch repository information for major ML frameworks.
    Returns a DataFrame with key metrics.
    """
    repos = ['tensorflow/tensorflow', 'pytorch/pytorch', 'scikit-learn/scikit-learn']
    api = GitHubAPI(token=os.getenv('GITHUB_TOKEN'))
    # Your code here
    repos_data=[]
    for i in range(len(repos)):
        owner,repo_name = repos[i].split("/")
        repo=api.get_repo(owner,repo_name)
        repo_data={
            "name":repo["name"],
            "stars":repo["stargazers_count"],
            "forks":repo["forks_count"],
            "language":repo["language"],
            "open_issues":repo["open_issues_count"],
            "created_date":repo["created_at"]
        }
        repos_data.append(repo_data)
    df = pd.DataFrame(repos_data)
    return df

# Call the function
df = task1_fetch_repos()
df.to_csv('task1_github.csv', index=False)
# Out:
# Rate Limit: 8/60
# Resets at: 2026-03-03 22:37:51
# ⚠️ Warning: Low on API requests!
# Rate Limit: 7/60
# Resets at: 2026-03-03 22:37:51
# ⚠️ Warning: Low on API requests!
# Rate Limit: 6/60
# Resets at: 2026-03-03 22:37:51
# ⚠️ Warning: Low on API requests!

# %%
df=pd.read_csv('task1_github.csv')
metric_df=df[["name"]]
metric_df["Age in days"]=(pd.to_datetime("today",utc=True)-pd.to_datetime(df["created_date"],utc=True)).dt.days
metric_df["Stars per day"]=df["stars"]/metric_df["Age in days"]
metric_df["Issues per star ratio"]=df["open_issues"]/df["stars"]
metric_df.to_csv('task1_metrics.csv', index=False)
# Out:
#            name   stars  forks language  open_issues          created_date
# 0    tensorflow  193959  75208      C++         3573  2015-11-07T01:19:20Z
# 1       pytorch   97898  27049   Python        18073  2016-08-13T05:26:41Z
# 2  scikit-learn   65262  26741   Python         2142  2010-08-17T09:43:38Z

# %%
import matplotlib.pyplot as plt
plt.style.use("dark_background")
fig,ax=plt.subplots(3,1,figsize=(10,15))
fig.suptitle("GitHub Repository Metrics Comparison", fontsize=16)
ax[0].bar(metric_df["name"],metric_df["Age in days"])
ax[0].set_ylabel("Age in days")
ax[0].set_xlabel("Repository")
ax[1].bar(metric_df["name"],metric_df["Stars per day"])
ax[1].set_ylabel("Stars per day")
ax[1].set_xlabel("Repository")
ax[2].bar(metric_df["name"],metric_df["Issues per star ratio"])
ax[2].set_ylabel("Issues per star ratio")
ax[2].set_xlabel("Repository")
plt.savefig("task1_comparison.png")
plt.close()

# %% [markdown]
# **1.2** *(5 points)* For each repo, calculate:
# - **Age in days** (from `created_date` to now)
# - **Stars per day**
# - **Issues per star ratio**
#
# Save as: **`task1_metrics.csv`**
#
# **1.3** *(5 points)* Create a **visualization** comparing the three repositories:
# - Save as: **`task1_comparison.png`**
# - Use `matplotlib` or `seaborn`
# - Compare **at least 3 metrics**
#
# ---
#
# ### 📋 Task 2: User Repository Analysis *(20 points)*
#
# **2.1** *(10 points)* Choose any GitHub user and fetch **ALL** their repositories (handle pagination)
#
# Requirements:
# - Implement **pagination** properly
# - Add **rate limiting** (wait 1 second between requests)
# - Handle errors gracefully
# - Log progress
#
# Save as: **`task2_all_repos.csv`**

# %%
def fetch_user_repos_paginated(username):
    """
    Fetch all repositories for a user with pagination.

    Args:
        username: GitHub username

    Returns:
        list: All repositories
    """
    
    all_repos = []
    page = 1
    url=f"https://api.github.com/users/{username}/repos"
    token = os.getenv('GITHUB_TOKEN')
    headers={'Authorization': f'Bearer {token}', 
            'Accept': 'application/vnd.github.v3+json',
            'User-Agent': 'Library-Tutorial/1.0'}
    logger = logging.getLogger(__name__)
    while True:
        try:
            params = {'page': page, 'per_page': 100}
            response = requests.get(url, params=params, headers=headers)
            response.raise_for_status()  
            if response.status_code==200:
                repos=response.json()
                logger.info(f"fetch page {page} and the result is {len(repos)} repos")
                if not repos:
                    logger.info(f"you've hit the last page {page}")
                    break
                all_repos.extend(repos)
            time.sleep(1)
            page+=1
        except Exception as e:
            logger.error(f"error fetching page {page}: {e}")
            break
    # Your implementation here
    # Remember to:
    # 1. Check for empty responses  --> means you've hit the last page
    # 2. Add delays                 --> time.sleep(1) to be polite
    # 3. Handle errors              --> try/except around requests
    # 4. Log progress               --> print or logger.info(f"Page {page}")

    return all_repos

# %%
fetch_user_repos_paginated("Nesma-Osama")
# Out:
# [{'id': 679021017,
#   'node_id': 'R_kgDOKHkJ2Q',
#   'name': '-AES-encryption-and-decryption.',
#   'full_name': 'Nesma-Osama/-AES-encryption-and-decryption.',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/-AES-encryption-and-decryption.',
#   'description': 'Verilog',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption.',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/-AES-encryption-and-decryption./deployments',
#   'created_at': '2023-08-15T23:43:22Z',
#   'updated_at': '2023-08-16T01:08:55Z',
#   'pushed_at': '2023-08-16T01:07:59Z',
#   'git_url': 'git://github.com/Nesma-Osama/-AES-encryption-and-decryption..git',
#   'ssh_url': 'git@github.com:Nesma-Osama/-AES-encryption-and-decryption..git',
#   'clone_url': 'https://github.com/Nesma-Osama/-AES-encryption-and-decryption..git',
#   'svn_url': 'https://github.com/Nesma-Osama/-AES-encryption-and-decryption.',
#   'homepage': None,
#   'size': 31,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 1,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 1,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 885073857,
#   'node_id': 'R_kgDONMEnwQ',
#   'name': 'AlphaSign-Flutter-CNN-Gesture-Classifier-App',
#   'full_name': 'Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App/deployments',
#   'created_at': '2024-11-07T22:53:17Z',
#   'updated_at': '2024-11-07T22:53:23Z',
#   'pushed_at': '2024-11-07T18:37:25Z',
#   'git_url': 'git://github.com/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App.git',
#   'clone_url': 'https://github.com/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App.git',
#   'svn_url': 'https://github.com/Nesma-Osama/AlphaSign-Flutter-CNN-Gesture-Classifier-App',
#   'homepage': None,
#   'size': 724,
#   'stargazers_count': 1,
#   'watchers_count': 1,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 1,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1038172532,
#   'node_id': 'R_kgDOPeFBdA',
#   'name': 'ANN-Classification-Churn',
#   'full_name': 'Nesma-Osama/ANN-Classification-Churn',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/ANN-Classification-Churn',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/ANN-Classification-Churn/deployments',
#   'created_at': '2025-08-14T18:31:01Z',
#   'updated_at': '2025-08-14T18:51:27Z',
#   'pushed_at': '2025-08-14T18:51:24Z',
#   'git_url': 'git://github.com/Nesma-Osama/ANN-Classification-Churn.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/ANN-Classification-Churn.git',
#   'clone_url': 'https://github.com/Nesma-Osama/ANN-Classification-Churn.git',
#   'svn_url': 'https://github.com/Nesma-Osama/ANN-Classification-Churn',
#   'homepage': None,
#   'size': 870,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1159616015,
#   'node_id': 'R_kgDORR5WDw',
#   'name': 'BigData',
#   'full_name': 'Nesma-Osama/BigData',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/BigData',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/BigData',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/BigData/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/BigData/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/BigData/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/BigData/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/BigData/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/BigData/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/BigData/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/BigData/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/BigData/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/BigData/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/BigData/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/BigData/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/BigData/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/BigData/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/BigData/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/BigData/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/BigData/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/BigData/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/BigData/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/BigData/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/BigData/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/BigData/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/BigData/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/BigData/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/BigData/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/BigData/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/BigData/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/BigData/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/BigData/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/BigData/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/BigData/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/BigData/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/BigData/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/BigData/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/BigData/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/BigData/deployments',
#   'created_at': '2026-02-17T00:03:46Z',
#   'updated_at': '2026-02-20T21:46:21Z',
#   'pushed_at': '2026-02-20T21:46:17Z',
#   'git_url': 'git://github.com/Nesma-Osama/BigData.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/BigData.git',
#   'clone_url': 'https://github.com/Nesma-Osama/BigData.git',
#   'svn_url': 'https://github.com/Nesma-Osama/BigData',
#   'homepage': None,
#   'size': 348,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'R',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 851100610,
#   'node_id': 'R_kgDOMrrDwg',
#   'name': 'Brute-Horse',
#   'full_name': 'Nesma-Osama/Brute-Horse',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/Brute-Horse',
#   'description': 'an automation pentesting interface that allows the disclosure of vulnerabilities in systems & even exploiting them',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/Brute-Horse/deployments',
#   'created_at': '2024-09-02T12:29:12Z',
#   'updated_at': '2025-05-16T14:37:00Z',
#   'pushed_at': '2025-05-16T14:36:56Z',
#   'git_url': 'git://github.com/Nesma-Osama/Brute-Horse.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/Brute-Horse.git',
#   'clone_url': 'https://github.com/Nesma-Osama/Brute-Horse.git',
#   'svn_url': 'https://github.com/Nesma-Osama/Brute-Horse',
#   'homepage': None,
#   'size': 947,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'TypeScript',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 727873921,
#   'node_id': 'R_kgDOK2J5gQ',
#   'name': 'CarAssembly',
#   'full_name': 'Nesma-Osama/CarAssembly',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/CarAssembly',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/CarAssembly/deployments',
#   'created_at': '2023-12-05T18:50:45Z',
#   'updated_at': '2023-12-05T18:51:49Z',
#   'pushed_at': '2023-12-05T18:52:54Z',
#   'git_url': 'git://github.com/Nesma-Osama/CarAssembly.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/CarAssembly.git',
#   'clone_url': 'https://github.com/Nesma-Osama/CarAssembly.git',
#   'svn_url': 'https://github.com/Nesma-Osama/CarAssembly',
#   'homepage': None,
#   'size': 9,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 730660124,
#   'node_id': 'R_kgDOK4z9HA',
#   'name': 'CarAssemblyPart2',
#   'full_name': 'Nesma-Osama/CarAssemblyPart2',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/CarAssemblyPart2',
#   'description': 'Obstacles and timer added',
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/CarAssemblyPart2/deployments',
#   'created_at': '2023-12-12T12:02:12Z',
#   'updated_at': '2023-12-13T10:48:24Z',
#   'pushed_at': '2023-12-12T12:04:13Z',
#   'git_url': 'git://github.com/Nesma-Osama/CarAssemblyPart2.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/CarAssemblyPart2.git',
#   'clone_url': 'https://github.com/Nesma-Osama/CarAssemblyPart2.git',
#   'svn_url': 'https://github.com/Nesma-Osama/CarAssemblyPart2',
#   'homepage': None,
#   'size': 17,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Assembly',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': False,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 865951917,
#   'node_id': 'R_kgDOM51grQ',
#   'name': 'CMP-Software-Engineering',
#   'full_name': 'Nesma-Osama/CMP-Software-Engineering',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/CMP-Software-Engineering',
#   'description': "Welcome to the Software Engineering Course Repository! This repository is designed to support students enrolled in CMP's Software Engineering course by providing a central hub for accessing course materials, lab assignments, and additional resources.",
#   'fork': True,
#   'url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/CMP-Software-Engineering/pulls{/number}',
# ...
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/Video-Classification-Cellula/deployments',
#   'created_at': '2025-08-07T16:07:06Z',
#   'updated_at': '2025-08-21T15:16:42Z',
#   'pushed_at': '2025-08-21T15:16:39Z',
#   'git_url': 'git://github.com/Nesma-Osama/Video-Classification-Cellula.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/Video-Classification-Cellula.git',
#   'clone_url': 'https://github.com/Nesma-Osama/Video-Classification-Cellula.git',
#   'svn_url': 'https://github.com/Nesma-Osama/Video-Classification-Cellula',
#   'homepage': None,
#   'size': 6132,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1029749594,
#   'node_id': 'R_kgDOPWC7Wg',
#   'name': 'Water-Segmentation-satellite',
#   'full_name': 'Nesma-Osama/Water-Segmentation-satellite',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/Water-Segmentation-satellite',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/Water-Segmentation-satellite/deployments',
#   'created_at': '2025-07-31T14:10:01Z',
#   'updated_at': '2025-07-31T19:40:39Z',
#   'pushed_at': '2025-07-31T19:40:35Z',
#   'git_url': 'git://github.com/Nesma-Osama/Water-Segmentation-satellite.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/Water-Segmentation-satellite.git',
#   'clone_url': 'https://github.com/Nesma-Osama/Water-Segmentation-satellite.git',
#   'svn_url': 'https://github.com/Nesma-Osama/Water-Segmentation-satellite',
#   'homepage': None,
#   'size': 1439,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 1081180486,
#   'node_id': 'R_kgDOQHGBRg',
#   'name': 'Who-Is-Talking',
#   'full_name': 'Nesma-Osama/Who-Is-Talking',
#   'private': False,
#   'owner': {'login': 'Nesma-Osama',
#    'id': 128908402,
#    'node_id': 'U_kgDOB678cg',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/128908402?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Nesma-Osama',
#    'html_url': 'https://github.com/Nesma-Osama',
#    'followers_url': 'https://api.github.com/users/Nesma-Osama/followers',
#    'following_url': 'https://api.github.com/users/Nesma-Osama/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Nesma-Osama/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Nesma-Osama/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Nesma-Osama/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Nesma-Osama/orgs',
#    'repos_url': 'https://api.github.com/users/Nesma-Osama/repos',
#    'events_url': 'https://api.github.com/users/Nesma-Osama/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Nesma-Osama/received_events',
#    'type': 'User',
#    'user_view_type': 'public',
#    'site_admin': False},
#   'html_url': 'https://github.com/Nesma-Osama/Who-Is-Talking',
#   'description': 'Who Is Talking (WIT) is a project aims to classify audio input and predict the gender, and age group using machine learning techniques.',
#   'fork': True,
#   'url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking',
#   'forks_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/forks',
#   'keys_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/teams',
#   'hooks_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/hooks',
#   'issue_events_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/events',
#   'assignees_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/tags',
#   'blobs_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/languages',
#   'stargazers_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/stargazers',
#   'contributors_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/contributors',
#   'subscribers_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/subscribers',
#   'subscription_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/subscription',
#   'commits_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/merges',
#   'archive_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/downloads',
#   'issues_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/Nesma-Osama/Who-Is-Talking/deployments',
#   'created_at': '2025-10-22T12:26:04Z',
#   'updated_at': '2025-10-22T12:26:04Z',
#   'pushed_at': '2025-05-08T09:20:22Z',
#   'git_url': 'git://github.com/Nesma-Osama/Who-Is-Talking.git',
#   'ssh_url': 'git@github.com:Nesma-Osama/Who-Is-Talking.git',
#   'clone_url': 'https://github.com/Nesma-Osama/Who-Is-Talking.git',
#   'svn_url': 'https://github.com/Nesma-Osama/Who-Is-Talking',
#   'homepage': '',
#   'size': 68167,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'has_discussions': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'web_commit_signoff_required': False,
#   'has_pull_requests': True,
#   'pull_request_creation_policy': 'all',
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'WIT',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}}]

# %% [markdown]
# **2.2** *(10 points)* Analyze the repositories:
# - Most used **programming language**
# - **Average stars** per repository
# - **Total forks** across all repos
# - **Most recently updated** repo
# - **Oldest** repo
#
# Create a summary report saved as: **`task2_analysis.txt`**
#
# ---
#
# ### 📋 Task 3: Advanced API Client *(15 points)*
#
# **3.1** *(15 points)* Build a complete `GitHubAnalyzer` class
#
# Requirements:
# - **Inherit from** or include rate limiting
# - Implement **retry logic** with exponential backoff
# - Add **logging**
# - Include these methods:
#   - `search_repos(query, language, min_stars)` — Search repositories
#   - `get_trending(language, since)` — Get trending repos
#   - `compare_repos(repo_list)` — Compare multiple repos
#   - `export_to_excel(df, filename)` — Export with formatting

# %%
class GitHubAnalyzer:
    """
    Complete GitHub API client with analysis capabilities.
    Build on top of the GitHubAPI class concepts from section 2.7.
    """

    def __init__(self, token=None):
        # Your initialization
        # Hint: Set up session, rate_limiter, logger like in GitHubAPI
        pass

    def search_repos(self, query, language=None, min_stars=0):
        """
        Search repositories with filters.

        Returns:
            DataFrame with results
        """
        pass

    def compare_repos(self, repo_list):
        """
        Compare multiple repositories.

        Args:
            repo_list: List of "owner/repo" strings

        Returns:
            DataFrame with comparison
        """
        pass

    def export_to_excel(self, df, filename):
        """
        Export DataFrame to Excel with formatting.
        - Bold headers
        - Auto-adjust column widths
        - Add creation timestamp
        """
        pass


# Test your class by:
# 1. Searching for "data science" repos in Python with >500 stars
# 2. Comparing 5 repos of your choice
# 3. Exporting results to task3_results.xlsx

# %% [markdown]
# ---
# ## 📦 Submission Requirements
#
# ### Files to submit:
#
# | # | File | Description |
# |---|---|---|
# | 1 | `github_analysis.py` | All your code |
# | 2 | `task1_github.csv` | Repo info table |
# | 3 | `task1_metrics.csv` | Calculated metrics |
# | 4 | `task1_comparison.png` | Visualization |
# | 5 | `task2_all_repos.csv` | All user repos |
# | 6 | `task2_analysis.txt` | Summary report |
# | 7 | `task3_results.xlsx` | Excel export |
# | 8 | `api_requests.log` | Your log file |
# | 9 | `README.md` | Brief report of findings |
#
# ---
#
# ### 📊 Grading Rubric:
#
# | Category | Weight |
# |---|---|
# | **Correct functionality** | 60% |
# | **Code quality** (comments, error handling, logging) | 20% |
# | **Output formatting** | 10% |
# | **Analysis insights** | 10% |
